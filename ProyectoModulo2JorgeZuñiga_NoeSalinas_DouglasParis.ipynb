# %% [markdown]
# ##  <font color= "grey">Materia :</font> <font color = "blue"> Simulacion Matematica </font>
# ## <font color= "grey">Proyecto :</font> "Ecuaciones diferenciales"

# %% [markdown]
# ##  <font color= "blue"> 1.2 Objetivos </font>

# %% [markdown]
# ### **           El objetivo general del proyecto es buscar a traves de ecuaciones diferenciales el seguimiento y crecimiento de las poblaciones en un ambiente, utilizando las herramientas del curso de Simulacion Matematica. **

# %% [markdown]
# ### <font color= "red">Objetivos especificos</font>

# %% [markdown]
#     · El trabajo tiene como objetivo el usar las herramientas aprendidas durante la segunda parte del curso de simulacion matematica
#
#       · Aplicar y resolver las ecuaciones diferenciales para graficar y tabular, la creacion de un mapa logistico a traves de una ecuación logistica.
#
#       · El uso de la funcion odeint.
#
#       · Modelar el espacio fase.

# %% [markdown]
# **Los componentes del trabajo son **
# 1. Importar bibliotecas.
# 2. Buscar las ecuaciones que satisfagan el comportamiento de una población.
# 3. Crear arrays, para manejar los datos.
# 4. Definir una matriz jacobiana.
# 5. Definir las condiciones iniciales para el ambiente.
# 6. Graficar las poblaciones de los conejos y zorros.
# 7. Hacer el espacio fase.

# %% [markdown]
# ## <font color = "blue"> 1.3 Modelo </font>

# %% [markdown]
# ### Condiciones y Restricciones

# %% [markdown]
#  Cada par de conejos tiene de media 10 crías al año.
#
#  Cada zorro captura 25 conejos al año de media.
#
#  La vida media de los zorros son 5 años.
#
#  El número de crías de zorro que sobrevive depende de que haya comida, es decir, es
# igual al número de conejos dividido entre 25.
#
#  El número medio de zorros es 100 y de conejos 500 en el área observada.

# %% [markdown]
# ### Situacion

# %% [markdown]
# El modelo va a representar la interaccion que tienen la poblacion de conejos, como presa, y la poblacion de lobos, como depredador, en un ambiente con las condiciones y restricciones del apartado anterior.

# %% [markdown]
# ### Ecuaciones

# %% [markdown]
# Las ecuaciones son:
#
#  $\frac{du}{dt} =  au -   buv$
#
#   $\frac{dv}{dt} = -cv + dbuv$
#
# Donde:
#
#   $u$: numero de presas (En nuestro caso son los conejos)
#
#   $v$: numero de depredadores (En nuestro caso son los zorros)
#
#   $a$, $b$, $c$, $d$ son parámetros constantes que definen el comportamiento de la población:
#
#   $a$ es la tasa de crecimiento natural de los conejos, cuando no hay zorros
#
#   $b$  es tasa de muerte natural de los conejos, debido a la depredación
#
#  $c$ es la tasa de muerte natural del zorro, cuando no hay conejos
#
#    $d$ es el factor que describe cuántos conejos capturados permiten crear un nuevo zorro

# %% [markdown]
# ## <font color = "blue"> 1.4 Simulaciones </font>

# %% [markdown]
# **Se resolvieron las ecuaciones diferenciales y primero se encontro el punto de equilibrio con ayuda de la matriz jacobian, con el equilibrio el modelo se comporta de la manera adecuada en 10 liebres y 5 zorros. Posteriormente graficamos los resultados con los valores de equilibrio, para despúes encontrar el espacio fase de la ecuación.**

# %% [markdown]
# ## <font color = "blue"> 1.5 Visualización </font>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pic = mpimg.imread("espacio_fase.jpg")
plt.imshow(pic)
plt.axis("off")
plt.show()

# %%
imagen = mpimg.imread("presacazador.jpg")
plt.imshow(imagen)
plt.axis("off")
plt.show()

# %% [markdown]
# ##  <font color = "blue" > 1.6 Conclusiones  </font>

# %% [markdown]
# *Nos hemos encontrado con un poco de dificultades durante el proyecto, debido a que ciertas ecuaciones son más complicadas que nuestro actual conocimiento de matemáticas. Aunque al no entender ciertas cosas, solo se investigaron para poder completar el proyecto. El objetivo general del proyecto se pudo lograr debido a que pudimos ver el comportamiento de las  poblaciones que interactuan en el medio ambiente con una relación presa-depredador.
# Se pudo segmentar el trabajo, como se menciona en "los componentes del trabajo" para lograr el programa de una manera ordenada y concisa, y aunque ya estamos familiarizados con el lenguaje de Python, las librerias importadas y Jupyter notebook, si se tuvo que profundizar en cuanto a funciones, y mejores tecnicas para lograr los graficos más complicados.*
#
# * Hay muchas situaciones en la naturaleza donde una especie animal se alimenta de otra, la cual a su vez se alimenta de otras cosas.
#
# **Ejemplo:**
# * Los zorros se alimentan de conejos, los cuales a su vez se alimentan de zanahorias. En este caso los zorros se denominan depredadores y los conejos serán las presas.
#
# ** Teóricamente, el depredador puede destruir toda la presa, de modo que esta última llegue a extinguirse. Sin embargo, si esto ocurre esta también se extinguirá, puesto que depende de la presa para su existencia.**
# ** De esta forma se desarrolla un ciclo en el cual la presa puede ser abundante y losdepredadores pocos, y luego, debido a la abundancia de presa, la población de depredadores aumenta, disminuyendo la primera, y el ciclo continua.**

# %% [markdown]
# ## <font color = "blue"> 1.7 Bibliografia </font>

# %% [markdown]
# E-spacio.uned.es. (2018). [online] Available at: http://e-spacio.uned.es/fez/eserv/bibliuned:masterMatavanz-Acano/Documento.pdf [Accessed 27 Jun. 2018].

# %% [markdown]
# Campus.fi.unju.edu.ar. (2018). [online] Available at: http://www.campus.fi.unju.edu.ar/courses/SPJ0001320082AP018/document/A.D.S.I_2013_-_APU_2008/UNIDAD_II/ejercicios_de_modelado.pdf?cidReq=SPJ0001320082AP018 [Accessed 27 Jun. 2018].
